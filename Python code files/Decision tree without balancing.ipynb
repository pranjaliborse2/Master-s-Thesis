# %%
import netCDF4
import xarray as xr
import numpy as np
import pandas as pd
import os, glob
import matplotlib.pyplot as plt
import geopandas as gpd
from datetime import timedelta
from scipy.stats import pearsonr, spearmanr
import cartopy.crs as ccrs
import seaborn as sns
from matplotlib.pyplot import figure

# %%
from ipynb.fs.defs.Chrisdata_analysis import buckdata, projection, monthly
csv = [pd.read_csv(f) for f in glob.glob("/data/dhence/a/pborse2/inputdata/ISWS_data/Champaign/*.csv")]
from ipynb.fs.defs.ISWSdataset_Champaign import aprnov
csvlist = [aprnov(csv)[i] for i in range(len(csv))]
os.chdir('/data/dhence/a/pborse2/inputdata/data.eol.ucar.edu/pub/download/extra/katz_data/stage4/daily_data')
fi = [f for f in glob.glob('*.nc')]
fi.sort()
# Out:
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# ...
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },
# /data/keeling/a/pborse2/Deanna Research/Research/Actual analysis/ISWSdataset_Champaign.ipynb:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   },

# %%
temp = pd.concat(csvlist)

# %%
rain = projection(fi)['tp'].sel(x=slice(734.5,737.5),y=slice(488,490.5)).mean(('x','y'))

# %%
missing = "2006-09-04T12:00:00.000000000"
miss1 = "2003-08-26T12:00:00.000000000"
# create an "empty" time slice with fillvalues
empty = xr.full_like(rain.isel(time=0), 0)
emp1 = xr.full_like(rain.isel(time=0), 0)
# fix the time coordinate of the timeslice
empty['time'] =pd.date_range(missing, periods=1)[0]
emp1['time']=pd.date_range(miss1, periods=1)[0]
# concat and sort time
rain = xr.concat([rain, empty,emp1], "time").sortby("time")

# %%
rain.plot.hist()
# Out:
# (array([5.923e+03, 3.780e+02, 1.240e+02, 7.200e+01, 2.800e+01, 7.000e+00,
#         5.000e+00, 2.000e+00, 4.000e+00, 3.000e+00]),
#  array([ 0.      ,  9.994444, 19.988888, 29.983334, 39.977776, 49.97222 ,
#         59.966667, 69.96111 , 79.95555 , 89.95    , 99.94444 ],
#        dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
dflar=[]
peaklarv=[]
for i in range(2003,2006):
    lar03 = pd.DataFrame(buckdata(i).sum(axis=1))
#     peaks, _ = find_peaks(lar03[lar03.index.month.isin(range(6,10))][0], height=0)
    peaks = np.percentile(lar03[lar03.index.month.isin(range(6,10))][0],85)
    peaks1=lar03[(lar03.index.month.isin(range(6,10)))&(lar03[0]>=peaks)][0]
    notpeaks = lar03[(lar03.index.month.isin(range(6,10)))&(lar03[0]<peaks)][0]
    r03 = rain.groupby('time.year')[i]
    plt.scatter(peaks1,r03[r03.time.dt.date.isin((peaks1.index-timedelta(1)).date)],color='red')
    plt.scatter(notpeaks,r03[r03.time.dt.date.isin((notpeaks.index-timedelta(1)).date)],color='blue')
    plt.axhline(5)
    # plt.scatter(lar03,r03[r03.time.dt.date.isin((lar03.index-timedelta(1)).date)])
    for k in range(8):
        lar03['rain'+str(k)] = r03[r03.time.dt.date.isin((lar03.index-timedelta(k)).date)].values
    for j in range(8):
        lar03['temp'+str(j)] = temp[temp.index.isin(lar03.index-timedelta(j))]['MAX AIR TEMP oF'].values
    dflar.append(lar03)
    peaklarv.append(peaks1)

# %%
dflar1 =pd.concat(dflar)
peaklarv1 = pd.concat(peaklarv)

# %%
dflar1['meantemp'] = dflar1[dflar1.columns[9:]].mean(axis=1)
dflar1['accumrain'] = dflar1[dflar1.columns[1:9]].sum(axis=1)
for i in range(2,8):
    dflar1['maxrain'+str(i)]=dflar1[dflar1.columns[3:i+1]].max(axis=1)
    dflar1['maxtemp'+str(i)]=dflar1[dflar1.columns[10:10+i]].max(axis=1)
    dflar1['accumrain'+str(i)]=dflar1[dflar1.columns[1:i+1]].sum(axis=1)

# %%
dflar1=dflar1[dflar1.index.month.isin(range(6,10))]
dflar1['bool']='false'
for i in range(len(dflar1)):
    if(list(peaklarv1.index.values).count(dflar1.index[i])>0):
        dflar1['bool'][i]='true'
##True  means larvae lows and false is larvae non-lows
# Out:
# /tmp/ipykernel_97508/3576082074.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dflar1['bool'][i]='true'

# %%
from sklearn.model_selection import train_test_split
 
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn import tree
from sklearn.model_selection import RepeatedStratifiedKFold, KFold
from sklearn.model_selection import cross_val_score
df = pd.get_dummies(dflar1.drop(columns='maxrain2'),drop_first=True)

# %%
df[0].hist(bins=30)
plt.title('distribution of larval counts (Imbalanced dataset)')
plt.ylabel('frequency')
plt.xlabel('counts')
plt.axvline(np.percentile(df[0],57),color='black')
plt.axvline(np.percentile(df[0],90),color='black')

# %%
np.percentile(df[0],100)
sorted(df[0])[300]
# Out:
# 151.0

# %%
df['cat']='L'
for i in range(len(df['cat'])):
    if(df[0][i]>=np.percentile(df[0],57) and df[0][i]<np.percentile(df[0],90)):
        df['cat'][i]='M'
    elif(df[0][i]>=np.percentile(df[0],90)):
        df['cat'][i]='H'
# Out:
# /tmp/ipykernel_99518/1572134349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cat'][i]='M'
# /tmp/ipykernel_99518/1572134349.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cat'][i]='H'

# %%
df[df['cat']=='H'][['maxrain'+str(k) for k in range(3,8)]+['rain1']].boxplot(ylabel='Rainfall (mm)',showmeans=True)
plt.title('Rainfall associated with High count category',fontsize=15)
plt.show()
df[df['cat']=='L'][['maxrain'+str(k) for k in range(3,8)]+['rain1']].boxplot(ylabel='Rainfall (mm)',showmeans=True)
plt.title('Rainfall associated with Low count category',fontsize=15)
plt.show()
df[df['cat']=='H'][['maxtemp'+str(k) for k in range(2,8)]].boxplot(ylabel='Temp (F)',showmeans=True)
plt.title('Temp associated with High count category',fontsize=15)
plt.show()
df[df['cat']=='L'][['maxtemp'+str(k) for k in range(2,8)]].boxplot(ylabel='Temp (F)',showmeans=True)
plt.title('Temp associated with Low count category',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Temp associated with Low count category')

# %%
df['cat'].hist()
plt.title('distribution of categories of larval counts based on percentile')
plt.ylabel('frequency')
plt.xlabel('categories')
# Out:
# Text(0.5, 0, 'categories')

# %%
df.boxplot(column=['maxrain7'],by='cat',ylabel='rainfall (mm)', xlabel='Larvae count category',showmeans=True)
df.boxplot(column=['rain1'],by='cat',ylabel='rainfall (mm)', xlabel='Larvae count category',showmeans=True)
df.boxplot(column=['maxtemp7'],by='cat',ylabel='Max. temp (F)', xlabel='Larvae count category',showmeans=True)
# Out:
# <AxesSubplot:title={'center':'maxtemp7'}, xlabel='Larvae count category', ylabel='Max. temp (F)'>

# %%
sns.distplot(df[df['cat']=='L']['maxtemp7'],hist=False)
sns.distplot(df[df['cat']=='M']['maxtemp7'],hist=False)
sns.distplot(df[df['cat']=='H']['maxtemp7'],hist=False)
# Out:
# /tmp/ipykernel_169787/20701865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['cat']=='L']['maxtemp7'],hist=False)
# /tmp/ipykernel_169787/20701865.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['cat']=='M']['maxtemp7'],hist=False)
# /tmp/ipykernel_169787/20701865.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['cat']=='H']['maxtemp7'],hist=False)
# <AxesSubplot:xlabel='maxtemp7', ylabel='Density'>

# %%
dfh = df[df['cat']=='H']
dfh[dfh['maxtemp7']<=np.percentile(dfh['maxtemp7'],25)][['maxrain7','rain1']].boxplot(showmeans=True,ylabel='Rainfall')
plt.ylim((-5,95))
plt.title('High counts \n rainfall associated with temp.-lower quartile')
plt.show()
dfh[(dfh['maxtemp7']>=np.percentile(dfh['maxtemp7'],25))&(dfh['maxtemp7']<=np.percentile(dfh['maxtemp7'],75))][['maxrain7','rain1']].boxplot(showmeans=True)
plt.title('High counts \n rainfall associated with temp.-central quartile')
plt.ylim(-5,95)
plt.show()
dfh[dfh['maxtemp7']>np.percentile(dfh['maxtemp7'],75)][['maxrain7','rain1']].boxplot(showmeans=True)
plt.title('High counts \n rainfall associated with temp.-upper quartile')
plt.ylim(-5,95)
# Out:
# (-5.0, 95.0)

# %%
df.to_csv('/data/dhence/a/pborse2/R_testfile')

# %%
from sklearn.datasets import fetch_openml

from sklearn.feature_selection import SelectKBest, SelectPercentile, mutual_info_classif

selector = SelectPercentile(mutual_info_classif, percentile=10)
X_reduced = selector.fit_transform(df.drop(columns=[0,'bool_true','cat']), df['cat'])
X_reduced.shape
# Out:
# (366, 4)

# %%
cols = selector.get_support(indices=True)
selected_columns =df.drop(columns=[0,'bool_true','cat']).iloc[:,cols].columns.tolist()
selected_columns
# Out:
# ['maxtemp5', 'maxtemp6', 'maxrain7', 'maxtemp7']

# %%
## Decision tree pruning using learning rate tuning


for i in ['maxrain'+str(k) for k in range(3,8)]:
    for j in ['maxtemp'+str(k) for k in range(2,8)]:
        X = df.copy(deep=True)[['cat',i,j]]
        y = X['cat']
        del X['cat']
        
        print(i,j)
        X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)
        
        dt = DecisionTreeClassifier(random_state=0)    
        
        path = dt.cost_complexity_pruning_path(X_train, y_train)
        ccp_alphas, impurities = path.ccp_alphas, path.impurities
        ccp_alphas = ccp_alphas[np.where(ccp_alphas>0)]
        dts = []
        for ccp_alpha in ccp_alphas:
            dt = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
            dt.fit(X_train, y_train)
            dts.append(dt)
        clfs = dts[:-1]
        ccp_alphas = ccp_alphas[:-1]
        node_counts = [clf.tree_.node_count for clf in clfs]
        depth = [clf.tree_.max_depth for clf in clfs]
#         plt.scatter(ccp_alphas,node_counts)
#         plt.scatter(ccp_alphas,depth)
#         plt.plot(ccp_alphas,node_counts,label='no of nodes',drawstyle="steps-post")
#         plt.plot(ccp_alphas,depth,label='depth',drawstyle="steps-post")
#         plt.legend()
#         plt.show()
        train_acc = []
        test_acc = []
        for c in clfs:
            y_train_pred = c.predict(X_train)
            y_test_pred = c.predict(X_test)
            train_acc.append(accuracy_score(y_train_pred,y_train))
            test_acc.append(accuracy_score(y_test_pred,y_test))

        plt.plot(ccp_alphas,train_acc,label='train_accuracy',drawstyle="steps-post",marker='o')
        plt.plot(ccp_alphas,test_acc,label='test_accuracy',drawstyle="steps-post",marker='o')
        plt.legend()
        plt.xlabel('Learning rate')
        plt.ylabel('Accuracy')
        plt.title('Accuracy vs alpha')
#         plt.scatter(depth,train_acc,label='train_accuracy',marker='*',c=ccp_alphas,cmap='plasma')
#         plt.scatter(depth,test_acc,label='test_accuracy',marker='o',c=ccp_alphas,cmap='plasma')
#         for k in range(len(ccp_alphas)):
#             plt.annotate(ccp_alphas[k], (depth[k], test_acc[k]))
#         plt.legend()
#         plt.title('Accuracy vs depth')
#         plt.colorbar()
        plt.show()
#         y_test_pred = model.predict(X_test)
# Out:
# maxrain3 maxtemp2
# maxrain3 maxtemp3
# maxrain3 maxtemp4
# maxrain3 maxtemp5
# maxrain3 maxtemp6
# maxrain3 maxtemp7
# maxrain4 maxtemp2
# maxrain4 maxtemp3
# maxrain4 maxtemp4
# maxrain4 maxtemp5
# maxrain4 maxtemp6
# maxrain4 maxtemp7
# maxrain5 maxtemp2
# maxrain5 maxtemp3
# maxrain5 maxtemp4
# maxrain5 maxtemp5
# maxrain5 maxtemp6
# maxrain5 maxtemp7
# maxrain6 maxtemp2
# maxrain6 maxtemp3
# maxrain6 maxtemp4
# maxrain6 maxtemp5
# maxrain6 maxtemp6
# maxrain6 maxtemp7
# maxrain7 maxtemp2
# maxrain7 maxtemp3
# maxrain7 maxtemp4
# maxrain7 maxtemp5
# maxrain7 maxtemp6
# maxrain7 maxtemp7

# %%
### Alpha when balance parameter considered
# maxrain2 maxtemp7 , 0.0053
# maxrain4 maxtemp5 , 0.003
# maxrain5 maxtemp3 , 0.003
# maxrain7 maxtemp6 , 0.0042

#### Alpha when balanced par not considered
# maxrain2 maxtemp7 , 0.005
# maxrain3 maxtemp7, 0.0055
# maxrain5 maxtemp7, 0.0068
# maxrain6 maxtemp2,0.006 
# maxrain7 maxtemp2, 0.0075
# maxrain7 maxtemp3, 0.005
# maxrain7 maxtemp4, 0.006

##### Evaluating performance of pruned model

from sklearn.metrics import confusion_matrix
from sklearn import tree
from sklearn.model_selection import RepeatedStratifiedKFold, KFold
from sklearn.model_selection import cross_val_score
from mlxtend.plotting import plot_confusion_matrix
import seaborn as sns



X = df.copy(deep=True)[['cat','maxrain6','maxtemp7']]

y = X['cat']

del X['cat']
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)
cv_outer = KFold(n_splits=10, shuffle=True, random_state=1)
# enumerate splits
outer_results = list()
models=[]
for train_ix, test_ix in cv_outer.split(X):
    # split data
    X_train, X_test = X.iloc[train_ix], X.iloc[test_ix]
    y_train, y_test = y.iloc[train_ix], y.iloc[test_ix]
    dt1 = DecisionTreeClassifier(random_state=0,ccp_alpha=0.0045,class_weight='balanced')

    dt1.fit(X_train, y_train)

    y_train_pred = dt1.predict(X_train)
    y_test_pred = dt1.predict(X_test)


    # tree.plot_tree(dt1.estimators_[0])

    print(f'Train score {accuracy_score(y_train_pred,y_train)}')

    sns.heatmap(confusion_matrix(y_train, y_train_pred),
              annot = True, fmt=".0f", annot_kws={"size":18},yticklabels=['H','L','M'],xticklabels=['H','L','M'])

    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    print(f'Test score {accuracy_score(y_test_pred,y_test)}')
    sns.heatmap(confusion_matrix(y_test, y_test_pred),
              annot = True, fmt=".0f", annot_kws={"size":18},yticklabels=['H','L','M'],xticklabels=['H','L','M'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    models.append(dt1)
# Out:
# Train score 0.7507598784194529
# Test score 0.5945945945945946
# Train score 0.790273556231003
# Test score 0.6486486486486487
# Train score 0.7963525835866262
# Test score 0.4864864864864865
# Train score 0.7720364741641338
# Test score 0.5135135135135135
# Train score 0.7720364741641338
# Test score 0.6756756756756757
# Train score 0.7872340425531915
# Test score 0.6756756756756757
# Train score 0.7515151515151515
# Test score 0.6666666666666666
# Train score 0.796969696969697
# Test score 0.7222222222222222
# Train score 0.7454545454545455
# Test score 0.6111111111111112
# Train score 0.7393939393939394
# Test score 0.5277777777777778

# %%
from graphviz import Source
 
from sklearn import tree
 
from IPython.display import SVG
from IPython.display import display 
 
import scipy.stats as sstats
graph = Source(tree.export_graphviz(models[-2], out_file=None,filled=True, feature_names=X.columns),format='png')

SVG(graph.pipe(format='svg'))
# tree.plot_tree(dt1,filled=True)
# plt.savefig('/data/dhence/a/pborse2/inputdata/out.pdf')

# %%
X = df.copy(deep=True)[['cat','maxrain6','maxtemp7']]
y = X['cat']
del X['cat']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

dt = DecisionTreeClassifier(random_state=0,ccp_alpha=0.002)

param_grid=dict(max_depth=range(3,6))
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=4, random_state=0)
grid = GridSearchCV(estimator= dt, param_grid=param_grid, n_jobs=-1, cv=cv)
#         grid.fit(X_train, y_train)
grid_result = grid.fit(X,y)
#         y_train_pred = grid_result.predict(X_train)
#         y_test_pred = grid_result.predict(X_test)

print('maxrain2','maxtemp7',grid.best_estimator_,grid.best_score_)
# Out:
# maxrain2 maxtemp7 DecisionTreeClassifier(ccp_alpha=0.002, max_depth=4, random_state=0) 0.61615990990991

# %%
from graphviz import Source
 
from sklearn import tree
 
from IPython.display import SVG
from IPython.display import display 
 
import scipy.stats as sstats
graph = Source(tree.export_graphviz(grid_result.best_estimator_, out_file=None,filled=True, feature_names=X.columns),format='png')

SVG(graph.pipe(format='svg'))

# %%
## Decision tree pruning using hyperparameter tuning 

# for i in ['maxrain'+str(k) for k in range(3,8)]:
#     for j in ['maxtemp'+str(k) for k in range(2,8)]:
for i in ['maxrain'+str(k) for k in range(4,7)]:
    X = df.copy(deep=True)[['cat',i,'maxtemp7']]
    y = X['cat']
    del X['cat']

    cv_outer = KFold(n_splits=10, shuffle=True, random_state=1)
    # enumerate splits
    outer_results = list()
    models=[]
    for train_ix, test_ix in cv_outer.split(X):
        # split data
        X_train, X_test = X.iloc[train_ix], X.iloc[test_ix]
        y_train, y_test = y.iloc[train_ix], y.iloc[test_ix]
        # configure the cross-validation procedure
        dt1 = DecisionTreeClassifier(random_state=0,class_weight='balanced')
        param_grid=dict(max_depth=range(3,8))
        cv = RepeatedStratifiedKFold(n_splits=7, n_repeats=4, random_state=0)
        grid = GridSearchCV(estimator=dt1, param_grid=param_grid, n_jobs=-1, cv=cv)
        grid_result = grid.fit(X_train, y_train)
        # get the best performing model fit on the whole training set
        best_model = grid_result.best_estimator_
        # evaluate model on the hold out dataset
        yhat = best_model.predict(X_test)
        # evaluate the model
        acc = accuracy_score(y_test, yhat)
        # store the result
        outer_results.append(acc)
        models.append(best_model)
        # report progress
        print('>acc=%.3f, est=%.3f, cfg=%s' % (acc, grid_result.best_score_, grid_result.best_params_))
        # summarize the estimated performance of the model
    print(i,j,'Accuracy: %.3f (%.3f)' % (np.mean(outer_results), np.std(outer_results)))
# Out:
# >acc=0.676, est=0.517, cfg={'max_depth': 7}
# >acc=0.568, est=0.547, cfg={'max_depth': 5}
# >acc=0.514, est=0.518, cfg={'max_depth': 7}
# >acc=0.622, est=0.533, cfg={'max_depth': 6}
# >acc=0.649, est=0.519, cfg={'max_depth': 7}
# >acc=0.568, est=0.569, cfg={'max_depth': 7}
# >acc=0.667, est=0.554, cfg={'max_depth': 7}
# >acc=0.583, est=0.549, cfg={'max_depth': 7}
# >acc=0.556, est=0.576, cfg={'max_depth': 7}
# >acc=0.611, est=0.546, cfg={'max_depth': 6}
# maxrain4 maxtemp7 Accuracy: 0.601 (0.050)
# >acc=0.649, est=0.511, cfg={'max_depth': 7}
# >acc=0.514, est=0.546, cfg={'max_depth': 7}
# >acc=0.568, est=0.546, cfg={'max_depth': 7}
# >acc=0.541, est=0.528, cfg={'max_depth': 7}
# >acc=0.622, est=0.547, cfg={'max_depth': 7}
# >acc=0.676, est=0.555, cfg={'max_depth': 7}
# >acc=0.722, est=0.568, cfg={'max_depth': 7}
# >acc=0.611, est=0.549, cfg={'max_depth': 7}
# >acc=0.583, est=0.562, cfg={'max_depth': 7}
# >acc=0.583, est=0.545, cfg={'max_depth': 5}
# maxrain5 maxtemp7 Accuracy: 0.607 (0.060)
# >acc=0.486, est=0.528, cfg={'max_depth': 7}
# >acc=0.405, est=0.574, cfg={'max_depth': 7}
# >acc=0.541, est=0.602, cfg={'max_depth': 7}
# >acc=0.622, est=0.535, cfg={'max_depth': 7}
# >acc=0.649, est=0.543, cfg={'max_depth': 7}
# >acc=0.622, est=0.533, cfg={'max_depth': 6}
# >acc=0.528, est=0.567, cfg={'max_depth': 7}
# >acc=0.611, est=0.576, cfg={'max_depth': 7}
# >acc=0.611, est=0.557, cfg={'max_depth': 7}
# >acc=0.500, est=0.564, cfg={'max_depth': 6}
# maxrain6 maxtemp7 Accuracy: 0.557 (0.074)

# %%
## Differentiation according to rainfall intensity

extrain = rain[rain>=20]
extrain = extrain[(extrain.time.dt.month.isin(range(6,10)))&(extrain.time.dt.year.isin(range(2003,2006)))]

vheavy = pd.to_datetime(['2004-06-10','2003-07-09','2003-08-31'])
heavy = pd.to_datetime(['2004-09-14','2003-06-11','2004-07-03','2003-07-17','2004-07-09'])
mod  = pd.to_datetime(extrain[~extrain.time.isin(vheavy.append(heavy))].time.values)

# %%
sns.set_style('whitegrid')
ax=sns.boxplot([dflar1[(dflar1.index).isin(vheavy+timedelta(1))][0],
                dflar1[(dflar1.index).isin(heavy+timedelta(1))][0],
                dflar1[(dflar1.index).isin((mod+timedelta(1)).date)][0]],
               
               width=0.3,palette='Blues')
ax.set_xticklabels(['Very heavy,\n high variability','Heavy,\n high variability','Moderate,\n low variability'])
# ax.set_title('Larvae counts associated with rainfall events')
plt.xlabel('Categories of rainfall',fontsize=14)
plt.ylabel('Larvae counts',fontsize=14)
plt.show()
